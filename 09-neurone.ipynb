# %% [markdown]
# # Lezione 9: I Mattoni delle Reti Neurali - Il Neurone 🧠
#
# Finora abbiamo visto modelli come gli Alberi Decisionali, di cui possiamo leggere le regole. Le Reti Neurali sono diverse: si ispirano liberamente al funzionamento del cervello umano per "intuire" le regole in modo più astratto.
#
# L'ispirazione viene dai **neuroni biologici**, cellule che ricevono segnali elettrici e, se il segnale è abbastanza forte, si "attivano" e lo passano ad altri neuroni.
#
# In questa lezione, non costruiremo un'intera rete, ma ci concentreremo su un singolo "mattone": il **neurone artificiale**. Capiremo come funziona con un semplice calcolo matematico.

# %% [markdown]
# Immaginiamo un neurone artificiale come una piccola macchina che prende decisioni. Ha 4 componenti fondamentali:
#
# 1.  **Input (x)**: Sono i dati che il neurone riceve. Sono semplicemente dei numeri.
#
# 2.  **Pesi (w)**: Ogni input ha un "peso" associato. Il peso rappresenta l'**importanza** di quell'input per la decisione finale. Un peso alto significa che l'input è molto influente, un peso basso significa che lo è poco. *Questa è la parte più importante!*
#
# 3.  **Bias (b)**: È un singolo numero che agisce come una sorta di "pollice verso l'alto o verso il basso". È una spinta iniziale che rende il neurone più o meno propenso ad attivarsi, a prescindere dagli input. Possiamo pensarlo come la sua "motivazione" o "pigrizia" di base.
#
# 4.  **Funzione di Attivazione**: È la regola finale che, dopo aver calcolato tutto, produce l'output. Per il nostro primo esempio, useremo la regola più semplice possibile: una **funzione a gradino**.
#     * Se il risultato dei calcoli è **maggiore di 0**, l'output del neurone è **1** (il neurone "si accende" 🔥).
#     * Se il risultato è **minore o uguale a 0**, l'output è **0** (il neurone "resta spento" 💤).
#
# Il calcolo che il neurone esegue è: **(Input_1 * Peso_1) + (Input_2 * Peso_2) + ... + Bias**. Il risultato di questa somma viene poi dato alla funzione di attivazione.
#
# ![Schema di un neurone artificiale](![OIP.VfVTsUPBw32b-51Z1VcZ7wHaDg.webp](data:image/webp;base64,...)https://i.imgur.com/K1j2v3j.png)![OIP.VfVTsUPBw32b-51Z1VcZ7wHaDg.webp](data:image/webp;base64,...)

# %% [markdown]
# ### Esempio: Il Neurone "Decido-se-Uscire"
#
# Il nostro neurone deve decidere se uscire di casa (Output = 1) o no (Output = 0).
# Ha **due input**:
# * `x1` (c'è il sole?): `1` se sì, `0` se no.
# * `x2` (gli amici sono liberi?): `1` se sì, `0` se no.
#
# **Parametri del neurone** (questi valori, nelle vere reti, vengono "imparati", ma per ora li decidiamo noi):
# * `w1` (importanza del sole): **0.5**
# * `w2` (importanza degli amici): **0.7** (gli amici sono un po' più importanti del sole)
# * `b` (bias, o "voglia di uscire"): **-0.8** (è un neurone pigro, ha bisogno di buone ragioni per attivarsi!)
#
# ---
# **SCENARIO 1: C'è il sole, ma gli amici sono occupati.**
# * `x1` = 1
# * `x2` = 0
#
# 1.  **Calcolo della somma pesata:**
#     `somma = (x1 * w1) + (x2 * w2)`
#     `somma = (1 * 0.5) + (0 * 0.7) = 0.5 + 0 = 0.5`
#
# 2.  **Aggiungiamo il bias:**
#     `risultato = somma + b`
#     `risultato = 0.5 + (-0.8) = -0.3`
#
# 3.  **Applichiamo la funzione di attivazione a gradino:**
#     `output = ?`
#     Poiché `-0.3` è minore di 0, l'output è **0**.
#
# **Conclusione: Il neurone ha deciso di NON USCIRE.** 💤
#
# ---
# **SCENARIO 2: C'è il sole E anche gli amici sono liberi!**
# * `x1` = 1
# * `x2` = 1
#
# 1.  **Calcolo della somma pesata:**
#     `somma = (x1 * w1) + (x2 * w2)`
#     `somma = (1 * 0.5) + (1 * 0.7) = 0.5 + 0.7 = 1.2`
#
# 2.  **Aggiungiamo il bias:**
#     `risultato = somma + b`
#     `risultato = 1.2 + (-0.8) = 0.4`
#
# 3.  **Applichiamo la funzione di attivazione a gradino:**
#     `output = ?`
#     Poiché `0.4` è maggiore di 0, l'output è **1**.
#
# **Conclusione: Il neurone ha deciso di USCIRE!** 🔥

# %% [markdown]
# Abbiamo appena visto in dettaglio come funziona un singolo "mattone". Una rete neurale non è altro che un insieme di questi mattoni, organizzati in **strati**:
#
# 1.  **Strato di Input**: Riceve i dati iniziali.
# 2.  **Strati Nascosti**: Squadre di neuroni che fanno calcoli intermedi. L'output di uno strato diventa l'input per quello successivo.
# 3.  **Strato di Output**: Produce la decisione finale.
#
# Il vero potere delle reti neurali, che vedremo nelle prossime lezioni, non sta in questo semplice calcolo, ma nella loro capacità di **imparare da sole i valori perfetti per migliaia di pesi e bias** analizzando tantissimi esempi.
#
# **Nella prossima lezione**, vedremo come questi neuroni si collegano in una catena per fare una previsione completa e come si misura se quella previsione è giusta o sbagliata.
